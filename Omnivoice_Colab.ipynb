# %% [markdown]
# # 🎙️ OmniVoice Thai on Google Colab
# เครื่องมือโคลนเสียงภาษาไทย รันบน Colab ฟรีด้วยรันไทม์ T4 GPU
#
# **วิธีการใช้งาน:**
# 1. ไปที่เมนู **Runtime** (รันไทม์) > **Change runtime type** (เปลี่ยนประเภทของรันไทม์)
# 2. เลือก **Hardware accelerator** เป็น **T4 GPU** แล้วกด Save
# 3. กดรันโค้ดแต่ละช่องเรียงจากบนลงล่าง

# %%
# 1. ตรวจสอบว่าได้รับการ์ดจอ (GPU) หรือยัง
# !nvidia-smi

# %%
# 2. ดาวน์โหลดโค้ดและติดตั้ง Dependencies (ใช้เวลาประมาณ 1-3 นาที)
# !git clone https://github.com/xIaMMaIx/Omnivoice_TH.git
# %cd Omnivoice_TH
# !pip install -r requirements.txt

# %%
# 3. เริ่มรันแอปพลิเคชัน
# เมื่อรันเสร็จแล้ว จะมีลิ้งก์ public สีฟ้าโผล่ขึ้นมา (เช่น https://xxxxxx.gradio.live)
# ให้คลิกที่ลิ้งก์นั้นเพื่อใช้งานได้เลย

from App import demo

# เปิด share=True เพื่อสร้าง Public URL
demo.launch(share=True)
